# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnymoon1314/Coaching_02_Real_Time_Streaming_Fraudulent_Transaction/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from Colab!")
# Out:
# Hello from Colab!
